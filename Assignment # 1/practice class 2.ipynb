# %%
print("Mustafa Raza Zuberi")
# Out:
# Mustafa Raza Zuberi

# %%
a = "Mustafa"
b = " Raza"
c = " Zuberi"
z = a + b + c
print(z)
# Out:
# Mustafa Raza Zuberi

# %%
x = 343
y = 787
s = x + y
print(s)
# Out:
# 1130

# %%
u = 88 - 8
u = 70 - 1
print(u)
# Out:
# 69

# %%
g = 5 
g = g + 5
print(g)
# Out:
# 10

# %%
h = 3
h+= 3
print(h)
# Out:
# 6

# %%
price = 799
price-=99
print(price)
# Out:
# 700

# %%
p = 600
p/=3
print(p)
# Out:
# 200.0

# %%
aa = "Inshallah Soon I will Joining"
bb = "Web and Mobile Apllication development "
cc = "Certifified Computer Accountant"
dd ="Batch 8"
zz = aa + cc +dd
print(zz)
# Out:
# Inshallah Soon I will JoiningCertifified Computer AccountantBatch 8

# %%
aa = "Inshallah Soon I will Joining "
bb = "Web and Mobile Apllication development "
cc = "Certifified Computer Accountant"
dd ="Batch 8"
zz = aa + bb +dd
print(zz)
# Out:
# Inshallah Soon I will Joining Web and Mobile Apllication development Batch 8

# %%
ab = "Mustafa Raza Zuberi"
bc = "My name is " + ab
print(bc)
# Out:
# My name is Mustafa Raza Zuberi

# %%
gender = "male"
if gender == "male":
    print("You are eligible")
else:
    print("You are not eligible")
# Out:
# You are eligible

# %%
gender = "female"
if gender == "male":
    print("You are eligible")
else:
    print("You are not eligible")
# Out:
# You are not eligible
