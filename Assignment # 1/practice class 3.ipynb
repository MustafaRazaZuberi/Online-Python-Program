# %%
english = 57 
islamiat = 99
chemistry = 88
total = 300 
obtain = english + islamiat + chemistry
percentage = obtain/total*100
if percentage <= 100 and percentage >= 80:
    print("A-one Grade");
elif percentage < 80 and percentage >= 70:
    print("A-Grade");
elif percentage < 70 and percentage >= 60:
    print("B-Grade");
elif percentage < 60 and percentage >= 50:
    print(C-Grade);
elif percentage < 50 and percentage >= 40:
    print(D-Grade);
elif percentage < 40 and percentage >= 33:
    print(E-Grade);
elif percentage < 33 and percentage > 1:
    print("Fail");
elif percentage > 100 and percentage < 0:
    print("Yo did not write marks correctly");
# Out:
# A-one Grade

# %%
english = int(input("Enter Your english Marks"))
islamiat = int(input("Enter Your islamiat Marks"))
chemistry = int(input("Enter Your chemistry Marks"))
total = 300 
obtain = english + islamiat + chemistry
percentage = obtain/total*100
if percentage <= 100 and percentage >= 80:
    print("A-one Grade");
elif percentage < 80 and percentage >= 70:
    print("A-Grade");
elif percentage < 70 and percentage >= 60:
    print("B-Grade");
elif percentage < 60 and percentage >= 50:
    print(C-Grade);
elif percentage < 50 and percentage >= 40:
    print(D-Grade);
elif percentage < 40 and percentage >= 33:
    print(E-Grade);
elif percentage < 33 and percentage > 1:
    print("Fail");
elif percentage > 100 and percentage < 0:
    print("Yo did not write marks correctly");
# Out:
# Enter Your english Marks99
# Enter Your islamiat Marks98
# Enter Your chemistry Marks98
# A-one Grade
