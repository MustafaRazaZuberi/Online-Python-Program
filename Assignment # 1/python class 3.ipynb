# %%
eng = 90;
isl = 77;
maths = 77; 
total = 300;
percent = (eng + isl + maths)/total*100;
if percent < 100 and percent >= 80:
    print("A+ grade");
elif percent < 80 and percent >= 70:
    print("A grade");
elif percent < 70 and percent >=60:
    print("B grade");
elif percent < 60 and pecent >= 50:
    print("C grade");
elif percent < 50 and pecent >= 40:
    print("D grade");
elif percent < 40 and pecent >= 33:
    print("E grade");
elif percent < 0 and percent > 100:
    print("You did not write percentage correctly");
else:
    print("Fail");
# Out:
# A+ grade

# %%
eng = int(input("enter english marks"));
isl = int(input("enter Islamiat marks"));
maths = int(input("enter maths marks")); 
total = 300;
percent = (eng + isl + maths)/total*100;
if percent < 100 and percent >= 80:
    print("A+ grade");
elif percent < 80 and percent >= 70:
    print("A grade");
elif percent < 70 and percent >=60:
    print("B grade");
elif percent < 60 and percent >= 50:
    print("C grade");
elif percent < 50 and percent >= 40:
    print("D grade");
elif percent < 40 and percent >= 33:
    print("E grade");
elif percent < 0 and percent > 100:
    print("You did not write percentage correctly");
else:
    print("Fail");
# Out:
# enter english marks88
# enter Islamiat marks87
# enter maths marks88
# A+ grade

# %%
x = int(input("enter a value"));
y = 25;
z = x + y;
print(z)
# Out:
# enter a value33
# 58

# %%
eng = int(input("enter english marks"));
isl = int(input("enter Islamiat marks"));
maths = int(input("enter maths marks")); 
total = 300;
percent = (eng + isl + maths)/total*100;
if percent < 100 and percent >= 80:
    print("A+ grade");
elif percent < 80 and percent >= 70:
    print("A grade");
elif percent < 70 and percent >=60:
    print("B grade");
elif percent < 60 and percent >= 50:
    print("C grade");
elif percent < 50 and percent >= 40:
    print("D grade");
elif percent < 40 and percent >= 33:
    print("E grade");
elif percent < 0 and percent > 100:
    print("You did not write percentage correctly");
else:
    print("Fail");
# Out:
# enter english marks33
# enter Islamiat marks23
# enter maths marks23
# Fail

# %%
x = int(input("enter a value"));
y = 25;
z = x + y;
print(z)
# Out:
# enter a value34
# 59

# %%
x = 8 ** 2
print(x)
# Out:
# 64

# %%
y = 4 ** 3
print(y)
# Out:
# 64

# %%
print("Mustafa\nRaza\nZuberi");
# Out:
# Mustafa
# Raza
# Zuberi

# %%
x = 6;
y = 7;
a = 20;
b = 7;
if x+y == a-b:
    print(True);
else:
    print(False);
# Out:
# True

# %%
age = int(input("enter your age"));
gender = input("enter your gender");
if age >= 18 or gender == male:
    print("Allowed");
else:
    print("Not Allowed");
# Out:
# enter your age18
# enter your genderfemale
# Allowed

# %%
age = int(input("enter your age"));
gender = input("enter your gender");
if age >= 18 and gender == "male":
    print("Allowed");
else:
    print("Not Allowed");
# Out:
# enter your age18
# enter your gendermale
# Allowed

# %%
age = int(input("enter your age"));
gender = input("enter your gender");
if age >= 18 and gender == "male":
    print("Allowed");
else:
    print("Not Allowed");
# Out:
# enter your age18
# enter your genderfemale
# Not Allowed

# %%
# List is defined by arr
arr = [117 , 87 , 23];
print(arr)
# Out:
# [117, 87, 23]

# %%
"""For multi line comments we enter comment in three inverted comma"""
print("Mustafa\nRaza\nZuberi")
# Out:
# mustafa
# Raza
# Zuberi

# %%
#List
name = ["Mustafa","Sameer","Wasif","Mohammad","Get S I"];
print(name);
# Out:
# ['Mustafa', 'Sameer', 'Wasif', 'Mohammad', 'Get S I']

# %%
name.append("Mn nai bataunga");
print(name);
# Out:
# ['Mustafa', 'Sameer', 'Wasif', 'Mohammad', 'Get S I', 'Mn nai bataunga']

# %%
print(name[0])
# Out:
# Mustafa

# %%
print(name[1]);
# Out:
# Sameer

# %%
name[2] = "Uzair"
print(name)
# Out:
# ['Mustafa', 'Sameer', 'Uzair', 'Mohammad', 'Get S I', 'Mn nai bataunga']

# %%
arr = ["mustafa",123,True,8.76]
print(arr)
# Out:
# ['mustafa', 123, True, 8.76]

# %%
newlist = name + arr;
print(newlist);
# Out:
# ['Mustafa', 'Sameer', 'Uzair', 'Mohammad', 'Get S I', 'Mn nai bataunga', 'mustafa', 123, True, 8.76]

# %%
print(name)
# Out:
# ['Mustafa', 'Sameer', 'Uzair', 'Mohammad', 'Get S I', 'Mn nai bataunga']

# %%
name.insert(2,"python programming")
print(name)
# Out:
# ['Mustafa', 'Sameer', 'python programming', 'Uzair', 'Mohammad', 'Get S I', 'Mn nai bataunga']

# %%
print(name)
# Out:
# ['Mustafa', 'Sameer', 'python programming', 'Uzair', 'Mohammad', 'Get S I', 'Mn nai bataunga']

# %%
name2 = name[0:3]
print(name2);
# Out:
# ['Mustafa', 'Sameer', 'python programming']

# %%
print(name)
# Out:
# ['Mustafa', 'Sameer', 'python programming', 'Uzair', 'Mohammad', 'Get S I', 'Mn nai bataunga']

# %%
del name[6];
print(name);
# Out:
# ['Mustafa', 'Sameer', 'python programming', 'Uzair', 'Mohammad', 'Get S I']

# %%
name.remove("Get S I");
print(name);
# Out:
# ['Mustafa', 'Sameer', 'python programming', 'Uzair', 'Mohammad']

# %%
name.pop()
print(name)
# Out:
# ['Mustafa', 'Sameer', 'python programming', 'Uzair']

# %%
x = input("")
y = " is joining Web and mobile App dev course"
z = x + y 
print(z)
# Out:
# Mustafa Raza Zuberi
# Mustafa Raza Zuberi is joining Web and mobile App dev course
